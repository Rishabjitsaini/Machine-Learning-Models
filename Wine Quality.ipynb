# %%
df = pd.read_csv(r"C:\Users\Rishab Saini\Downloads\wine+quality\winequality-white.csv",delimiter=';')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
df['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# Length: 4898, dtype: bool

# %%
##Removing the duplicated record
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (3961, 12)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='box',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df['fixed acidity'],kde=True)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Count'>

# %%
df.quality.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='alcohol',y='pH',hue='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='pH'>

# %%
plt.figure(figsize=(20,10))
corr_columns = df.corr()
sns.heatmap(corr_columns,annot = True, fmt =".2f", cmap = "coolwarm")
plt.title(' Corealtion of columns')
# Out:
# Text(0.5, 1.0, ' Corealtion of columns')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.019214     0.298959
# volatile acidity          -0.019214          1.000000    -0.163228
# citric acid                0.298959         -0.163228     1.000000
# residual sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free sulfur dioxide       -0.058396         -0.102471     0.091681
# total sulfur dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                        -0.431274         -0.046954    -0.183015
# sulphates                 -0.017453         -0.021150     0.049442
# alcohol                   -0.110788          0.046815    -0.076514
# quality                   -0.124636         -0.190678     0.007065
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
X = df.drop(['quality'], axis=1)
y = df.quality

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)

# %%
scaled_X_test=scaler.fit_transform(X_test)

# %%
X_test=scaler.transform(X_test)
X_test
# Out:
# array([[ 0.3625095 ,  0.3241541 ,  1.0924714 , ..., -1.07874262,
#         -0.67740285,  1.66834521],
#        [ 3.08448943, -0.42936993,  0.93159182, ..., -2.94779573,
#         -0.13992789,  0.19151786],
#        [ 0.3625095 , -0.14679842,  3.26434578, ..., -1.01429251,
#         -0.40866537, -1.5314474 ],
#        ...,
#        [-0.83516167,  1.36024964,  0.1271939 , ...,  1.11256104,
#          0.12880959, -1.69553933],
#        [-0.18188649, -0.99451295, -0.43588464, ..., -0.56314176,
#         -0.31908621,  0.27356382],
#        [ 2.21345585,  0.13577309,  0.1271939 , ..., -0.30534133,
#         -0.31908621,  0.76583961]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score,f1_score
from sklearn.linear_model import LinearRegression,LogisticRegression

# %%
regression= LogisticRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# C:\Users\Rishab Saini\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LogisticRegression()
# Out:
# LogisticRegression()

# %%
from sklearn.svm import SVR, LinearSVR #linear kernel

# %%
import pickle

# %%
pickle.dump(regression,open('wine_lr_model.pickle','wb'))

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 04C2-793D
#
#  Directory of C:\Users\Rishab Saini\python BIT\ML
#
# 09-10-2023  11:02           983,034 (SVC)BreastCancer.ipynb
# 09-10-2023  11:03    <DIR>          .
# 20-09-2023  11:31    <DIR>          ..
# 09-10-2023  11:02    <DIR>          .ipynb_checkpoints
# 25-09-2023  11:11               600 admission_lr_model.pickle
# 25-09-2023  11:10            34,093 Advertising DataSet.ipynb
# 05-10-2023  12:07            25,630 Breast_cancer_SVC.ipynb
# 04-10-2023  11:56           622,387 CONCERT_SLUMPS.ipynb
# 04-10-2023  12:06               589 credit_approval.ipynb
# 27-09-2023  12:04           127,138 Diabetes_DataSet.ipynb
# 27-09-2023  12:00               772 diabetes_logistic_model.pickle
# 26-09-2023  11:40           499,949 LInear regression_admission prediction.ipynb
# 05-10-2023  11:12             8,874 RED_wine Dataset.ipynb
# 09-10-2023  11:02           768,594 Wine Quality.ipynb
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
test1=scaler.transform([[7.4,0.70,0.00,1.9,0.076,11.0,34.0,0.9978,3.51,0.56,9.4]])
test1
# Out:
# C:\Users\Rishab Saini\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 0.58026789,  3.90339324, -2.68819882, -0.85530079,  1.35962117,
#         -1.3196683 , -2.41410299,  1.42137008,  2.01486254,  0.66628454,
#         -0.95712565]])

# %%
regression.predict(test1)
# Out:
# C:\Users\Rishab Saini\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([5], dtype=int64)

# %%
regression.score(X_test,y_test)
# Out:
# C:\Users\Rishab Saini\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0.31786074672048437

# %%
regression.score(X_train,y_train)
# Out:
# 0.48383838383838385

# %%
regression.predict(test1)
# Out:
# C:\Users\Rishab Saini\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([5], dtype=int64)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
base_model = SVR()

# %%
base_model.fit(scaled_X_train, y_train)
# Out:
# SVR()

# %%
base_preds = base_model.predict(X_test)

# %%
base_preds
# Out:
# array([6.35823194, 4.80803857, 5.18426507, 5.71187046, 6.08313614,
#        5.66314795, 6.2983037 , 5.38657997, 5.73596932, 5.75535632,
#        5.38265089, 5.64062244, 5.37495561, 5.16315199, 5.16566549,
#        5.94799618, 5.34073451, 6.32732837, 5.51866963, 4.9032937 ,
#        5.8742965 , 5.17730272, 6.22771067, 5.7036504 , 5.96654895,
#        6.26674546, 6.31273333, 6.04831004, 5.35581915, 6.05841249,
#        5.06824951, 5.30214828, 5.55220304, 5.37997726, 5.64180188,
#        5.35266224, 6.04323146, 5.50339933, 4.8829438 , 5.9933557 ,
#        6.20237213, 5.8904904 , 5.3501113 , 5.06169357, 4.99685775,
#        4.76164473, 6.05722056, 6.00284445, 5.58130319, 5.93752012,
#        6.39619404, 6.62462598, 6.08935698, 5.79619873, 5.12056466,
#        6.02238631, 5.11926822, 6.74237965, 6.4797    , 5.55995949,
#        5.91816114, 5.38291232, 5.77891898, 6.41585949, 7.03055873,
#        6.17585699, 5.11200086, 4.92900212, 6.41743992, 5.8383072 ,
# ...

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
mean_absolute_error(y_test,base_preds)
# Out:
# 0.5578720406622223

# %%
np.sqrt(mean_squared_error(y_test, base_preds))
# Out:
# 0.7264453876899412

# %%
y_test.mean()
# Out:
# 5.852674066599395

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[0.001,0.01,0.1,0.5,1],'kernel':['linear','rbf','poly'],'gamma':['scale','auto'],'degree':[2,3,4],'epsilon':[0,0.01,0.1,0.5,1,2]}

# %%
param_grid
# Out:
# {'C': [0.001, 0.01, 0.1, 0.5, 1],
#  'kernel': ['linear', 'rbf', 'poly'],
#  'gamma': ['scale', 'auto'],
#  'degree': [2, 3, 4],
#  'epsilon': [0, 0.01, 0.1, 0.5, 1, 2]}

# %%
svr=SVR()

# %%
grid_model = GridSearchCV(svr, param_grid)

# %%
grid_model.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1], 'degree': [2, 3, 4],
#                          'epsilon': [0, 0.01, 0.1, 0.5, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
grid_model.best_params_
# Out:
# {'C': 0.5, 'degree': 2, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
grid_preds = grid_model.predict(scaled_X_test)

# %%
mean_absolute_error(y_test,grid_preds)
# Out:
# 0.5593797993988503

# %%
np.sqrt(mean_squared_error(y_test,grid_preds))
# Out:
# 0.7305413370562018
